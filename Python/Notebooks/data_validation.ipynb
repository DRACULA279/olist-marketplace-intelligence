# %%
import pandas as pd
import os
import sys

sys.path.append(
    os.path.abspath("../scripts")
)

from db_connection import engine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       3 import sys
#       5 sys.path.append(
#       6     os.path.abspath("../scripts")
#       7 )
# ----> 9 from db_connection import engine
#
# ModuleNotFoundError: No module named 'db_connection'
